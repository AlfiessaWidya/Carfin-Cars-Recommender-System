# %% [markdown]
# ## Import Library

# %%
import json
from bert_score import score
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ## Fine-Tuning Model Evaluation

# %% [markdown]
# ### With Accuracy

# %%
def compute_bertscore(system_response, reference_responses):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        # Pastikan semua elemen dalam list adalah string
        reference_responses = [str(ref) for ref in reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Mengembalikan rata-rata BERTScore
    return P.mean().item(), R.mean().item(), F1.mean().item()


# Fungsi untuk menghitung Cosine Similarity menggunakan Sentence-BERT
def compute_cosine_similarity(system_response, reference_responses, model):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        reference_responses = [str(ref) for ref in reference_responses]

    system_embedding = model.encode(system_response, convert_to_tensor=True)
    reference_embeddings = model.encode(reference_responses, convert_to_tensor=True)
    cosine_scores = util.cos_sim(system_embedding, reference_embeddings)
    return cosine_scores

# Fungsi untuk menghitung BERT Accuracy
def compute_bert_accuracy(system_response, reference_responses, threshold=0.7):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        reference_responses = [str(ref) for ref in reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Hitung accuracy berdasarkan threshold
    matches = (F1 >= threshold).float()
    accuracy = matches.mean().item()
    
    return accuracy

# Memuat data dari file JSON
with open('fine_tuning_evals.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Memuat model Sentence-BERT
model = SentenceTransformer('all-MiniLM-L6-v2')

# Menyimpan hasil evaluasi
bertscore_results = []
cosine_results = []
accuracy_results = []

# Proses evaluasi untuk setiap item dalam data
for item in data:
    system_response = str(item["system_response"])  # Pastikan system_response adalah string
    reference_responses = item["reference_responses"]  # Akan dikonversi di dalam fungsi
    
    # Menghitung BERTScore
    bert_precision, bert_recall, bert_f1 = compute_bertscore(system_response, reference_responses)
    bertscore_results.append((bert_precision, bert_recall, bert_f1))
    
    # Menghitung Cosine Similarity
    cosine_scores = compute_cosine_similarity(system_response, reference_responses, model)
    cosine_results.append(cosine_scores)
    
    # Menghitung BERT Accuracy
    accuracy = compute_bert_accuracy(system_response, reference_responses)
    accuracy_results.append(accuracy)

# Menampilkan hasil BERTScore, Cosine Similarity, dan BERT Accuracy untuk setiap item
for i, item in enumerate(data):
    print(f"Item {i+1} - User Query: {item['user_query']}")
    print(f"System Response: {item['system_response']}")
    print(f"Reference Responses: {item['reference_responses']}")
    print(f"BERTScore - Precision: {bertscore_results[i][0]:.4f}, Recall: {bertscore_results[i][1]:.4f}, F1: {bertscore_results[i][2]:.4f}")
    print(f"BERT Accuracy: {accuracy_results[i]:.4f}")
    
    # Menampilkan Cosine Similarity untuk setiap reference
    print(f"Cosine Similarity with reference responses:")
    for j, score in enumerate(cosine_results[i][0]):
        print(f"  Reference {j+1}: {score.item():.4f}")
    
    print("\n" + "-"*80 + "\n")

# Menampilkan rata-rata metrik untuk seluruh dataset
avg_bert_precision = sum([result[0] for result in bertscore_results]) / len(bertscore_results)
avg_bert_recall = sum([result[1] for result in bertscore_results]) / len(bertscore_results)
avg_bert_f1 = sum([result[2] for result in bertscore_results]) / len(bertscore_results)
avg_bert_accuracy = sum(accuracy_results) / len(accuracy_results)

print(f"Average BERT Precision: {avg_bert_precision:.4f}")
print(f"Average BERT Recall: {avg_bert_recall:.4f}")
print(f"Average BERT F1: {avg_bert_f1:.4f}")
print(f"Average BERT Accuracy: {avg_bert_accuracy:.4f}")

# Menampilkan rata-rata Cosine Similarity untuk seluruh dataset
avg_cosine_similarity = sum([score.mean().item() for score in cosine_results]) / len(cosine_results)
print(f"Average Cosine Similarity: {avg_cosine_similarity:.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Item 1 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Passo Model 2013 (2013)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 144,151,500.
# Reference Responses: Toyota Passo Model 2013 with automatic transmission price below 150 million rupiah. A 2013 car with a mileage of 90,000 km using gasoline. Equipped with ABS and air bag safety features, AC comfort, audio, rear camera, and keyless entry. Car price IDR 144,151,500.
# BERTScore - Precision: 0.8187, Recall: 0.8828, F1: 0.8496
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8181
#
# --------------------------------------------------------------------------------
#
# Item 2 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Mira Xs3 2020
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 53000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 200,116,200
# Reference Responses: Daihatsu Mira Xs3 2020 model with automatic transmission is priced below 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline fuel. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200.
# BERTScore - Precision: 0.8560, Recall: 0.8990, F1: 0.8770
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8247
#
# --------------------------------------------------------------------------------
#
# Item 3 - User Query: Car with complete safety features between 150-300 million
# System Response: 🚗 Honda City
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 107000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, AM
# • FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Honda City 2018 with automatic transmission is priced between 150-300 million rupiah. Car year 2018 with a mileage of 107,000 km using gasoline. Equipped with ABS, AM FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 214,814,000.
# BERTScore - Precision: 0.8473, Recall: 0.8911, F1: 0.8686
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7505
#
# --------------------------------------------------------------------------------
#
# Item 4 - User Query: Car with good entertainment system around 180 million
# System Response: 🚗 Honda city (2018)
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 20000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, AM
# • FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 214,531,350
# Reference Responses: Honda City 2018 with automatic transmission costs around 180 million rupiah. Car year 2018 with a mileage of 20,000 km using gasoline. Equipped with ABS, Air Bags, AM FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8475, Recall: 0.9023, F1: 0.8741
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7431
#
# --------------------------------------------------------------------------------
#
# Item 5 - User Query: Find me a Daihatsu automatic with complete features
# System Response: 🚗 Mira XSA3 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 79000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# • FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks
# 💰 Price (IDR): IDR 178,069,500
# Reference Responses: A Daihatsu Mira XSA3 with automatic transmission costs around 170 million rupiah. Car year 2018 with a mileage of 79,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# - FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks. Car price IDR 178,069,500.
# BERTScore - Precision: 0.8785, Recall: 0.9197, F1: 0.8986
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7786
#
# --------------------------------------------------------------------------------
#
# Item 6 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Mira X 2018 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 5800 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 197,855,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 200 million rupiah. 2018 car with a mileage of 5,800 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price Rp 197,855,000.
# BERTScore - Precision: 0.8524, Recall: 0.9107, F1: 0.8806
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7486
#
# --------------------------------------------------------------------------------
#
# Item 7 - User Query: Toyota with leather seats and automatic transmission
# System Response: 🚗 Altis 2018 (2018)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 55000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# • FM Radio, CD Player
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: A Toyota Altis with automatic transmission costs around 250 million rupiah. 2018 car with 55,000 km mileage using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AMFM Radio, CD Player. Car price IDR 245,905,500.
# BERTScore - Precision: 0.8376, Recall: 0.8993, F1: 0.8674
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7938
#
# --------------------------------------------------------------------------------
#
# Item 8 - User Query: Low mileage honda car with complete safety features
# System Response: 🚗 Honda city (2018)
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 20000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, AM
# • FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 214,531,350
# Reference Responses: A Honda City with automatic transmission costs around 200 million rupiah. 2018 car with 20,000 km mileage using gasoline. Equipped with ABS, Air Bags, AM
# - FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8539, Recall: 0.9084, F1: 0.8803
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7219
#
# --------------------------------------------------------------------------------
#
# Item 9 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki every (2018)
# 📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 100000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera
# 💰 Price (IDR): IDR 155,457,500
# Reference Responses: Suzuki every year 2018 with automatic transmission costs around 150 million rupiah. The 2018 car with a mileage of 100,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera. Car price Rp 155,457,500.
# BERTScore - Precision: 0.8615, Recall: 0.9107, F1: 0.8854
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7068
#
# --------------------------------------------------------------------------------
#
# Item 10 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira with automatic transmission costs around 200 million rupiah. The 2019 car with a mileage of 37,500 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable. Car price IDR 206,334,500.
# BERTScore - Precision: 0.8854, Recall: 0.9284, F1: 0.9064
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7982
#
# --------------------------------------------------------------------------------
#
# Item 11 - User Query: Toyota 2023 model with complete features under 300 million
# System Response: 🚗 Toyota Yaris (2023)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Toyota Yaris with automatic transmission costs around 260 million rupiah. The 2023 car with a mileage of 37,500 km uses gasoline. Equipped with Air Bags. Car price IDR 260,038,000.
# BERTScore - Precision: 0.8125, Recall: 0.8824, F1: 0.8460
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7544
#
# --------------------------------------------------------------------------------
#
# Item 12 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Mira X 2018 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 70000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning
# 💰 Price (IDR): IDR 192,202,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 190 million rupiah. 2018 car with a mileage of 70,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning. Car price Rp 192,202,000.
# BERTScore - Precision: 0.8198, Recall: 0.8874, F1: 0.8523
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7058
#
# --------------------------------------------------------------------------------
#
# Item 13 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Toyota Passo 2014 (2014)
# 📝 Detail Mobil:
# • Merek: Toyota
# • KMs Driven: 82000 km
# • Bahan Bakar: Petrol
# • Transmisi: Automatic
# 🌟 Fitur:
# • ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera
# 💰 Harga: IDR 157,153,400
# Reference Responses: A Toyota Passo with automatic transmission costs around 157 million rupiah. The 2014 car with a mileage of 82,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera. Car price IDR IDR 157,153,400.
# BERTScore - Precision: 0.8542, Recall: 0.9045, F1: 0.8786
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.6511
#
# --------------------------------------------------------------------------------
#
# Item 14 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Mira Xs3 2020
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 53000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 200,116,200
# Reference Responses: A Mira Xs3 with automatic transmission costs around 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM
# - FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200
# BERTScore - Precision: 0.8636, Recall: 0.9122, F1: 0.8872
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7922
#
# --------------------------------------------------------------------------------
#
# Item 15 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki Every 2018 (2018)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 92000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 146,130,050
# Reference Responses: Suzuki Every 2018 with 92,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows. Price: IDR 146,130,050.
# BERTScore - Precision: 0.8464, Recall: 0.9268, F1: 0.8848
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9094
#
# --------------------------------------------------------------------------------
#
# Item 16 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 51000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 179,482,750
# Reference Responses: Daihatsu Mira 2019 with 51,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows. Price: IDR 179,482,750.
# BERTScore - Precision: 0.8481, Recall: 0.9268, F1: 0.8857
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9029
#
# --------------------------------------------------------------------------------
#
# Item 17 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki Every (2018)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 79000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio
# 💰 Price (IDR): IDR 139,629,100
# Reference Responses: Suzuki Every 2018 with 79,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio. Price: IDR 139,629,100.
# BERTScore - Precision: 0.8208, Recall: 0.9161, F1: 0.8658
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9113
#
# --------------------------------------------------------------------------------
#
# Item 18 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Mira XSAIII (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 67000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 195,028,500
# Reference Responses: Daihatsu Mira XSAIII 2021 with 67,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable. Price: IDR 195,028,500.
# BERTScore - Precision: 0.8854, Recall: 0.9385, F1: 0.9111
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8626
#
# --------------------------------------------------------------------------------
#
# Item 19 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8741, Recall: 0.9320, F1: 0.9021
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9167
#
# --------------------------------------------------------------------------------
#
# Item 20 - User Query: Low mileage Toyota car with complete safety features
# System Response: 🚗 Corolla Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 12300 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Toyota Corolla Gli 2019 with 12,300 km, petrol fuel, and automatic transmission. Features include Air Conditioning. Price: IDR 214,814,000.
# BERTScore - Precision: 0.8150, Recall: 0.9183, F1: 0.8636
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9004
#
# --------------------------------------------------------------------------------
#
# Item 21 - User Query: Looking for a car with manual transmission, price between 150 to 300 million
# System Response: 🚗 Honda City (2022)
#  📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Conditioning, AM, FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 226,120,000
# Reference Responses: Honda City 2022 with 16,000 km, petrol fuel, and manual transmission. Features include ABS, Air Conditioning, AM FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 226,120,000.
# BERTScore - Precision: 0.8567, Recall: 0.9274, F1: 0.8906
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8655
#
# --------------------------------------------------------------------------------
#
# Item 22 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: Toyota Passo 2021 with 6,900 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable. Price: IDR 245,905,500.
# BERTScore - Precision: 0.8645, Recall: 0.9306, F1: 0.8963
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9175
#
# --------------------------------------------------------------------------------
#
# Item 23 - User Query: Suzuki car with low kilometers and complete features
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 24 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Daihatsu Move (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Daihatsu Move 2021 with 6,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 197,798,470.
# BERTScore - Precision: 0.8767, Recall: 0.9317, F1: 0.9034
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9115
#
# --------------------------------------------------------------------------------
#
# Item 25 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Yaris 2021 (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 31000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera
# 💰 Price (IDR): IDR 245,622,850
# Reference Responses: Toyota Yaris 2021 with 31,000 km, petrol fuel, and automatic transmission. Features include Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera. Price: IDR 245,622,850.
# BERTScore - Precision: 0.8538, Recall: 0.9345, F1: 0.8923
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8981
#
# --------------------------------------------------------------------------------
#
# Item 26 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 27 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Gli (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 243,079,000
# Reference Responses: Toyota Gli 2019 with 90,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows. Price: IDR 243,079,000.
# BERTScore - Precision: 0.8742, Recall: 0.9357, F1: 0.9039
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9277
#
# --------------------------------------------------------------------------------
#
# Item 28 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Yaris (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 24000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning, Alloy Rims, AM, FM Radio, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 234,599,500
# Reference Responses: Toyota Yaris 2021 with 24,000 km, petrol fuel, and automatic transmission. Features include Air Conditioning, Alloy Rims, AM FM Radio, Power Locks, Power Steering, Power Windows. Price: IDR 234,599,500.
# BERTScore - Precision: 0.8406, Recall: 0.9270, F1: 0.8817
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9081
#
# --------------------------------------------------------------------------------
#
# Item 29 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 30 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Corolla GLI (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 41000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 237,426,000
# Reference Responses: Toyota Corolla GLI 2019 with 41,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable. Price: IDR 237,426,000.
# BERTScore - Precision: 0.8649, Recall: 0.9329, F1: 0.8976
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9269
#
# --------------------------------------------------------------------------------
#
# Item 31 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8508, Recall: 0.9277, F1: 0.8876
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7476
#
# --------------------------------------------------------------------------------
#
# Item 32 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira ES (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 57000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 175,243,000
# Reference Responses: Daihatsu Mira ES 2019 with 57,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 175,243,000.
# BERTScore - Precision: 0.8635, Recall: 0.9291, F1: 0.8951
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8968
#
# --------------------------------------------------------------------------------
#
# Item 33 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8508, Recall: 0.9277, F1: 0.8876
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7476
#
# --------------------------------------------------------------------------------
#
# Item 34 - User Query: Suzuki 2022 model with complete features under 200 million
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 35 - User Query: Suzuki 2023 model with complete features under 200 million
# System Response: 🚗 Suzuki Alto VXL (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Alto VXL 2023 with 7,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 166,763,500.
# BERTScore - Precision: 0.8603, Recall: 0.9228, F1: 0.8905
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9164
#
# --------------------------------------------------------------------------------
#
# Average BERT Precision: 0.8541
# Average BERT Recall: 0.9183
# Average BERT F1: 0.8850
# Average BERT Accuracy: 1.0000
# Average Cosine Similarity: 0.8372

# %% [markdown]
# ### Without Accuracy

# %%
# Fungsi untuk menghitung BERTScore
def compute_bertscore(system_response, reference_responses):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Mengembalikan rata-rata BERTScore
    return P.mean().item(), R.mean().item(), F1.mean().item()


# Fungsi untuk menghitung Cosine Similarity menggunakan Sentence-BERT
def compute_cosine_similarity(system_response, reference_responses, model):
    system_embedding = model.encode(system_response, convert_to_tensor=True)
    reference_embeddings = model.encode(reference_responses, convert_to_tensor=True)
    cosine_scores = util.cos_sim(system_embedding, reference_embeddings)
    return cosine_scores

# Memuat data dari file JSON
with open('fine_tuning_evals.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Memuat model Sentence-BERT
model = SentenceTransformer('all-MiniLM-L6-v2')

# Menyimpan hasil evaluasi
bertscore_results = []
cosine_results = []

# Proses evaluasi untuk setiap item dalam data
for item in data:
    system_response = item["system_response"]
    reference_responses = item["reference_responses"]
    
    # Menghitung BERTScore
    bert_precision, bert_recall, bert_f1 = compute_bertscore(system_response, reference_responses)
    bertscore_results.append((bert_precision, bert_recall, bert_f1))
    
    # Menghitung Cosine Similarity
    cosine_scores = compute_cosine_similarity(system_response, reference_responses, model)
    cosine_results.append(cosine_scores)

# Menampilkan hasil BERTScore dan Cosine Similarity untuk setiap item
for i, item in enumerate(data):
    print(f"Item {i+1} - User Query: {item['user_query']}")
    print(f"System Response: {item['system_response']}")
    print(f"Reference Responses: {item['reference_responses']}")
    print(f"BERTScore - Precision: {bertscore_results[i][0]:.4f}, Recall: {bertscore_results[i][1]:.4f}, F1: {bertscore_results[i][2]:.4f}")
    
    # Menampilkan Cosine Similarity untuk setiap reference
    print(f"Cosine Similarity with reference responses:")
    for j, score in enumerate(cosine_results[i][0]):
        print(f"  Reference {j+1}: {score.item():.4f}")
    
    print("\n" + "-"*80 + "\n")

# Menampilkan rata-rata BERTScore untuk seluruh dataset
avg_bert_precision = sum([result[0] for result in bertscore_results]) / len(bertscore_results)
avg_bert_recall = sum([result[1] for result in bertscore_results]) / len(bertscore_results)
avg_bert_f1 = sum([result[2] for result in bertscore_results]) / len(bertscore_results)

print(f"Average BERT Precision: {avg_bert_precision:.4f}")
print(f"Average BERT Recall: {avg_bert_recall:.4f}")
print(f"Average BERT F1: {avg_bert_f1:.4f}")

# Menampilkan rata-rata Cosine Similarity untuk seluruh dataset
avg_cosine_similarity = sum([score.mean().item() for score in cosine_results]) / len(cosine_results)
print(f"Average Cosine Similarity: {avg_cosine_similarity:.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Item 1 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Passo Model 2013 (2013)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM/FM Radio, CD Player, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 144,151,500.
# Reference Responses: Toyota Passo Model 2013 with automatic transmission price below 150 million rupiah. A 2013 car with a mileage of 90,000 km using gasoline. Equipped with ABS and air bag safety features, AC comfort, audio, rear camera, and keyless entry. Car price IDR 144,151,500.
# BERTScore - Precision: 0.8187, Recall: 0.8828, F1: 0.8496
# Cosine Similarity with reference responses:
#   Reference 1: 0.8181
#
# --------------------------------------------------------------------------------
#
# Item 2 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Mira Xs3 2020
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 53000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 200,116,200
# Reference Responses: Daihatsu Mira Xs3 2020 model with automatic transmission is priced below 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline fuel. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200.
# BERTScore - Precision: 0.8560, Recall: 0.8990, F1: 0.8770
# Cosine Similarity with reference responses:
#   Reference 1: 0.8247
#
# --------------------------------------------------------------------------------
#
# Item 3 - User Query: Car with complete safety features between 150-300 million
# System Response: 🚗 Honda City
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 107000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, AM
# • FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Honda City 2018 with automatic transmission is priced between 150-300 million rupiah. Car year 2018 with a mileage of 107,000 km using gasoline. Equipped with ABS, AM FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 214,814,000.
# BERTScore - Precision: 0.8473, Recall: 0.8911, F1: 0.8686
# Cosine Similarity with reference responses:
#   Reference 1: 0.7505
#
# --------------------------------------------------------------------------------
#
# Item 4 - User Query: Car with good entertainment system around 180 million
# System Response: 🚗 Honda city (2018)
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 20000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, AM
# • FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 214,531,350
# Reference Responses: Honda City 2018 with automatic transmission costs around 180 million rupiah. Car year 2018 with a mileage of 20,000 km using gasoline. Equipped with ABS, Air Bags, AM FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8475, Recall: 0.9023, F1: 0.8741
# Cosine Similarity with reference responses:
#   Reference 1: 0.7431
#
# --------------------------------------------------------------------------------
#
# Item 5 - User Query: Find me a Daihatsu automatic with complete features
# System Response: 🚗 Mira XSA3 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 79000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# • FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks
# 💰 Price (IDR): IDR 178,069,500
# Reference Responses: A Daihatsu Mira XSA3 with automatic transmission costs around 170 million rupiah. Car year 2018 with a mileage of 79,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# - FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks. Car price IDR 178,069,500.
# BERTScore - Precision: 0.8785, Recall: 0.9197, F1: 0.8986
# Cosine Similarity with reference responses:
#   Reference 1: 0.7786
#
# --------------------------------------------------------------------------------
#
# Item 6 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Mira X 2018 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 5800 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 197,855,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 200 million rupiah. 2018 car with a mileage of 5,800 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price Rp 197,855,000.
# BERTScore - Precision: 0.8524, Recall: 0.9107, F1: 0.8806
# Cosine Similarity with reference responses:
#   Reference 1: 0.7486
#
# --------------------------------------------------------------------------------
#
# Item 7 - User Query: Toyota with leather seats and automatic transmission
# System Response: 🚗 Altis 2018 (2018)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 55000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM
# • FM Radio, CD Player
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: A Toyota Altis with automatic transmission costs around 250 million rupiah. 2018 car with 55,000 km mileage using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AMFM Radio, CD Player. Car price IDR 245,905,500.
# BERTScore - Precision: 0.8376, Recall: 0.8993, F1: 0.8674
# Cosine Similarity with reference responses:
#   Reference 1: 0.7938
#
# --------------------------------------------------------------------------------
#
# Item 8 - User Query: Low mileage honda car with complete safety features
# System Response: 🚗 Honda city (2018)
# 📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 20000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, AM
# • FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 214,531,350
# Reference Responses: A Honda City with automatic transmission costs around 200 million rupiah. 2018 car with 20,000 km mileage using gasoline. Equipped with ABS, Air Bags, AM
# - FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8539, Recall: 0.9084, F1: 0.8803
# Cosine Similarity with reference responses:
#   Reference 1: 0.7219
#
# --------------------------------------------------------------------------------
#
# Item 9 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki every (2018)
# 📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 100000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera
# 💰 Price (IDR): IDR 155,457,500
# Reference Responses: Suzuki every year 2018 with automatic transmission costs around 150 million rupiah. The 2018 car with a mileage of 100,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, Cassette Player, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera. Car price Rp 155,457,500.
# BERTScore - Precision: 0.8615, Recall: 0.9107, F1: 0.8854
# Cosine Similarity with reference responses:
#   Reference 1: 0.7068
#
# --------------------------------------------------------------------------------
#
# Item 10 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira with automatic transmission costs around 200 million rupiah. The 2019 car with a mileage of 37,500 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera, USB and Auxillary Cable. Car price IDR 206,334,500.
# BERTScore - Precision: 0.8854, Recall: 0.9284, F1: 0.9064
# Cosine Similarity with reference responses:
#   Reference 1: 0.7982
#
# --------------------------------------------------------------------------------
#
# Item 11 - User Query: Toyota 2023 model with complete features under 300 million
# System Response: 🚗 Toyota Yaris (2023)
# 📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Toyota Yaris with automatic transmission costs around 260 million rupiah. The 2023 car with a mileage of 37,500 km uses gasoline. Equipped with Air Bags. Car price IDR 260,038,000.
# BERTScore - Precision: 0.8125, Recall: 0.8824, F1: 0.8460
# Cosine Similarity with reference responses:
#   Reference 1: 0.7544
#
# --------------------------------------------------------------------------------
#
# Item 12 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Mira X 2018 (2018)
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 70000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning
# 💰 Price (IDR): IDR 192,202,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 190 million rupiah. 2018 car with a mileage of 70,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning. Car price Rp 192,202,000.
# BERTScore - Precision: 0.8198, Recall: 0.8874, F1: 0.8523
# Cosine Similarity with reference responses:
#   Reference 1: 0.7058
#
# --------------------------------------------------------------------------------
#
# Item 13 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Toyota Passo 2014 (2014)
# 📝 Detail Mobil:
# • Merek: Toyota
# • KMs Driven: 82000 km
# • Bahan Bakar: Petrol
# • Transmisi: Automatic
# 🌟 Fitur:
# • ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera
# 💰 Harga: IDR 157,153,400
# Reference Responses: A Toyota Passo with automatic transmission costs around 157 million rupiah. The 2014 car with a mileage of 82,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera. Car price IDR IDR 157,153,400.
# BERTScore - Precision: 0.8542, Recall: 0.9045, F1: 0.8786
# Cosine Similarity with reference responses:
#   Reference 1: 0.6511
#
# --------------------------------------------------------------------------------
#
# Item 14 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Mira Xs3 2020
# 📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 53000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM
# • FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 200,116,200
# Reference Responses: A Mira Xs3 with automatic transmission costs around 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM
# - FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200
# BERTScore - Precision: 0.8636, Recall: 0.9122, F1: 0.8872
# Cosine Similarity with reference responses:
#   Reference 1: 0.7922
#
# --------------------------------------------------------------------------------
#
# Item 15 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki Every 2018 (2018)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 92000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 146,130,050
# Reference Responses: Suzuki Every 2018 with 92,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows. Price: IDR 146,130,050.
# BERTScore - Precision: 0.8464, Recall: 0.9268, F1: 0.8848
# Cosine Similarity with reference responses:
#   Reference 1: 0.9094
#
# --------------------------------------------------------------------------------
#
# Item 16 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 51000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 179,482,750
# Reference Responses: Daihatsu Mira 2019 with 51,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows. Price: IDR 179,482,750.
# BERTScore - Precision: 0.8481, Recall: 0.9268, F1: 0.8857
# Cosine Similarity with reference responses:
#   Reference 1: 0.9029
#
# --------------------------------------------------------------------------------
#
# Item 17 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Suzuki Every (2018)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 79000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio
# 💰 Price (IDR): IDR 139,629,100
# Reference Responses: Suzuki Every 2018 with 79,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio. Price: IDR 139,629,100.
# BERTScore - Precision: 0.8208, Recall: 0.9161, F1: 0.8658
# Cosine Similarity with reference responses:
#   Reference 1: 0.9113
#
# --------------------------------------------------------------------------------
#
# Item 18 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Mira XSAIII (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 67000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 195,028,500
# Reference Responses: Daihatsu Mira XSAIII 2021 with 67,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable. Price: IDR 195,028,500.
# BERTScore - Precision: 0.8854, Recall: 0.9385, F1: 0.9111
# Cosine Similarity with reference responses:
#   Reference 1: 0.8626
#
# --------------------------------------------------------------------------------
#
# Item 19 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8741, Recall: 0.9320, F1: 0.9021
# Cosine Similarity with reference responses:
#   Reference 1: 0.9167
#
# --------------------------------------------------------------------------------
#
# Item 20 - User Query: Low mileage Toyota car with complete safety features
# System Response: 🚗 Corolla Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 12300 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Toyota Corolla Gli 2019 with 12,300 km, petrol fuel, and automatic transmission. Features include Air Conditioning. Price: IDR 214,814,000.
# BERTScore - Precision: 0.8150, Recall: 0.9183, F1: 0.8636
# Cosine Similarity with reference responses:
#   Reference 1: 0.9004
#
# --------------------------------------------------------------------------------
#
# Item 21 - User Query: Looking for a car with manual transmission, price between 150 to 300 million
# System Response: 🚗 Honda City (2022)
#  📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Conditioning, AM, FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 226,120,000
# Reference Responses: Honda City 2022 with 16,000 km, petrol fuel, and manual transmission. Features include ABS, Air Conditioning, AM FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 226,120,000.
# BERTScore - Precision: 0.8567, Recall: 0.9274, F1: 0.8906
# Cosine Similarity with reference responses:
#   Reference 1: 0.8655
#
# --------------------------------------------------------------------------------
#
# Item 22 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: Toyota Passo 2021 with 6,900 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable. Price: IDR 245,905,500.
# BERTScore - Precision: 0.8645, Recall: 0.9306, F1: 0.8963
# Cosine Similarity with reference responses:
#   Reference 1: 0.9175
#
# --------------------------------------------------------------------------------
#
# Item 23 - User Query: Suzuki car with low kilometers and complete features
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 24 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Daihatsu Move (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Daihatsu Move 2021 with 6,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 197,798,470.
# BERTScore - Precision: 0.8767, Recall: 0.9317, F1: 0.9034
# Cosine Similarity with reference responses:
#   Reference 1: 0.9115
#
# --------------------------------------------------------------------------------
#
# Item 25 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Yaris 2021 (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 31000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera
# 💰 Price (IDR): IDR 245,622,850
# Reference Responses: Toyota Yaris 2021 with 31,000 km, petrol fuel, and automatic transmission. Features include Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera. Price: IDR 245,622,850.
# BERTScore - Precision: 0.8538, Recall: 0.9345, F1: 0.8923
# Cosine Similarity with reference responses:
#   Reference 1: 0.8981
#
# --------------------------------------------------------------------------------
#
# Item 26 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 27 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Gli (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 243,079,000
# Reference Responses: Toyota Gli 2019 with 90,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows. Price: IDR 243,079,000.
# BERTScore - Precision: 0.8742, Recall: 0.9357, F1: 0.9039
# Cosine Similarity with reference responses:
#   Reference 1: 0.9277
#
# --------------------------------------------------------------------------------
#
# Item 28 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Yaris (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 24000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning, Alloy Rims, AM, FM Radio, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 234,599,500
# Reference Responses: Toyota Yaris 2021 with 24,000 km, petrol fuel, and automatic transmission. Features include Air Conditioning, Alloy Rims, AM FM Radio, Power Locks, Power Steering, Power Windows. Price: IDR 234,599,500.
# BERTScore - Precision: 0.8406, Recall: 0.9270, F1: 0.8817
# Cosine Similarity with reference responses:
#   Reference 1: 0.9081
#
# --------------------------------------------------------------------------------
#
# Item 29 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 30 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Corolla GLI (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 41000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 237,426,000
# Reference Responses: Toyota Corolla GLI 2019 with 41,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable. Price: IDR 237,426,000.
# BERTScore - Precision: 0.8649, Recall: 0.9329, F1: 0.8976
# Cosine Similarity with reference responses:
#   Reference 1: 0.9269
#
# --------------------------------------------------------------------------------
#
# Item 31 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8508, Recall: 0.9277, F1: 0.8876
# Cosine Similarity with reference responses:
#   Reference 1: 0.7476
#
# --------------------------------------------------------------------------------
#
# Item 32 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira ES (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 57000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 175,243,000
# Reference Responses: Daihatsu Mira ES 2019 with 57,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 175,243,000.
# BERTScore - Precision: 0.8635, Recall: 0.9291, F1: 0.8951
# Cosine Similarity with reference responses:
#   Reference 1: 0.8968
#
# --------------------------------------------------------------------------------
#
# Item 33 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8508, Recall: 0.9277, F1: 0.8876
# Cosine Similarity with reference responses:
#   Reference 1: 0.7476
#
# --------------------------------------------------------------------------------
#
# Item 34 - User Query: Suzuki 2022 model with complete features under 200 million
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 35 - User Query: Suzuki 2023 model with complete features under 200 million
# System Response: 🚗 Suzuki Alto VXL (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Alto VXL 2023 with 7,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 166,763,500.
# BERTScore - Precision: 0.8603, Recall: 0.9228, F1: 0.8905
# Cosine Similarity with reference responses:
#   Reference 1: 0.9164
#
# --------------------------------------------------------------------------------
#
# Average BERT Precision: 0.8541
# Average BERT Recall: 0.9183
# Average BERT F1: 0.8850
# Average Cosine Similarity: 0.8372

# %% [markdown]
# ## Pre Fine-Tuning Model Evaluation

# %% [markdown]
# ### With Accuracy

# %%
def compute_bertscore(system_response, reference_responses):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        # Pastikan semua elemen dalam list adalah string
        reference_responses = [str(ref) for ref in reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Mengembalikan rata-rata BERTScore
    return P.mean().item(), R.mean().item(), F1.mean().item()


# Fungsi untuk menghitung Cosine Similarity menggunakan Sentence-BERT
def compute_cosine_similarity(system_response, reference_responses, model):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        reference_responses = [str(ref) for ref in reference_responses]

    system_embedding = model.encode(system_response, convert_to_tensor=True)
    reference_embeddings = model.encode(reference_responses, convert_to_tensor=True)
    cosine_scores = util.cos_sim(system_embedding, reference_embeddings)
    return cosine_scores

# Fungsi untuk menghitung BERT Accuracy
def compute_bert_accuracy(system_response, reference_responses, threshold=0.7):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    elif isinstance(reference_responses, list):
        reference_responses = [str(ref) for ref in reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Hitung accuracy berdasarkan threshold
    matches = (F1 >= threshold).float()
    accuracy = matches.mean().item()
    
    return accuracy

# Memuat data dari file JSON
with open('pre_fine_tuning_evals.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Memuat model Sentence-BERT
model = SentenceTransformer('all-MiniLM-L6-v2')

# Menyimpan hasil evaluasi
bertscore_results = []
cosine_results = []
accuracy_results = []

# Proses evaluasi untuk setiap item dalam data
for item in data:
    system_response = str(item["system_response"])  # Pastikan system_response adalah string
    reference_responses = item["reference_responses"]  # Akan dikonversi di dalam fungsi
    
    # Menghitung BERTScore
    bert_precision, bert_recall, bert_f1 = compute_bertscore(system_response, reference_responses)
    bertscore_results.append((bert_precision, bert_recall, bert_f1))
    
    # Menghitung Cosine Similarity
    cosine_scores = compute_cosine_similarity(system_response, reference_responses, model)
    cosine_results.append(cosine_scores)
    
    # Menghitung BERT Accuracy
    accuracy = compute_bert_accuracy(system_response, reference_responses)
    accuracy_results.append(accuracy)

# Menampilkan hasil BERTScore, Cosine Similarity, dan BERT Accuracy untuk setiap item
for i, item in enumerate(data):
    print(f"Item {i+1} - User Query: {item['user_query']}")
    print(f"System Response: {item['system_response']}")
    print(f"Reference Responses: {item['reference_responses']}")
    print(f"BERTScore - Precision: {bertscore_results[i][0]:.4f}, Recall: {bertscore_results[i][1]:.4f}, F1: {bertscore_results[i][2]:.4f}")
    print(f"BERT Accuracy: {accuracy_results[i]:.4f}")
    
    # Menampilkan Cosine Similarity untuk setiap reference
    print(f"Cosine Similarity with reference responses:")
    for j, score in enumerate(cosine_results[i][0]):
        print(f"  Reference {j+1}: {score.item():.4f}")
    
    print("\n" + "-"*80 + "\n")

# Menampilkan rata-rata metrik untuk seluruh dataset
avg_bert_precision = sum([result[0] for result in bertscore_results]) / len(bertscore_results)
avg_bert_recall = sum([result[1] for result in bertscore_results]) / len(bertscore_results)
avg_bert_f1 = sum([result[2] for result in bertscore_results]) / len(bertscore_results)
avg_bert_accuracy = sum(accuracy_results) / len(accuracy_results)

print(f"Average BERT Precision: {avg_bert_precision:.4f}")
print(f"Average BERT Recall: {avg_bert_recall:.4f}")
print(f"Average BERT F1: {avg_bert_f1:.4f}")
print(f"Average BERT Accuracy: {avg_bert_accuracy:.4f}")

# Menampilkan rata-rata Cosine Similarity untuk seluruh dataset
avg_cosine_similarity = sum([score.mean().item() for score in cosine_results]) / len(cosine_results)
print(f"Average Cosine Similarity: {avg_cosine_similarity:.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Item 1 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Toyota Passo 2014 (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 82000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 157,153,400
# Reference Responses: Toyota Passo Model 2013 with automatic transmission price below 150 million rupiah. A 2013 car with a mileage of 90,000 km using gasoline. Equipped with ABS and air bag safety features, AC comfort, audio, rear camera, and keyless entry. Car price IDR 144,151,500.
# BERTScore - Precision: 0.8090, Recall: 0.8753, F1: 0.8408
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7866
#
# --------------------------------------------------------------------------------
#
# Item 2 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Altis 2016 (2016)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 80000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 196,159,100
# Reference Responses: Daihatsu Mira Xs3 2020 model with automatic transmission is priced below 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline fuel. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200.
# BERTScore - Precision: 0.8304, Recall: 0.8855, F1: 0.8571
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.4657
#
# --------------------------------------------------------------------------------
#
# Item 3 - User Query: Car with complete safety features between 150-300 million
# System Response: 🚗 Toyota Grande (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 145000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cruise Control, DVD Player, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 224,706,750
# Reference Responses: Honda City 2018 with automatic transmission is priced between 150-300 million rupiah. Car year 2018 with a mileage of 107,000 km using gasoline. Equipped with ABS, AM FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 214,814,000.
# BERTScore - Precision: 0.8319, Recall: 0.8845, F1: 0.8574
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.2708
#
# --------------------------------------------------------------------------------
#
# Item 4 - User Query: Car with good entertainment system around 180 million
# System Response: 🚗 Gli Auto 2014 (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning, DVD Player, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 180,896,000
# Reference Responses: Honda City 2018 with automatic transmission costs around 180 million rupiah. Car year 2018 with a mileage of 20,000 km using gasoline. Equipped with ABS, Air Bags, AM FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8182, Recall: 0.8699, F1: 0.8433
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.4177
#
# --------------------------------------------------------------------------------
#
# Item 5 - User Query: Find me a Daihatsu automatic with complete features
# System Response: 🚗 Daihatsu Mira 2019 (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 51000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 179,482,750
# Reference Responses: A Daihatsu Mira XSA3 with automatic transmission costs around 170 million rupiah. Car year 2018 with a mileage of 79,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM - FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks. Car price IDR 178,069,500.
# BERTScore - Precision: 0.8301, Recall: 0.8641, F1: 0.8468
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7473
#
# --------------------------------------------------------------------------------
#
# Item 6 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 200 million rupiah. 2018 car with a mileage of 5,800 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price Rp 197,855,000.
# BERTScore - Precision: 0.8250, Recall: 0.9007, F1: 0.8612
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7474
#
# --------------------------------------------------------------------------------
#
# Item 7 - User Query: Toyota with leather seats and automatic transmission
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: A Toyota Altis with automatic transmission costs around 250 million rupiah. 2018 car with 55,000 km mileage using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AMFM Radio, CD Player. Car price IDR 245,905,500.
# BERTScore - Precision: 0.8190, Recall: 0.8910, F1: 0.8535
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.5546
#
# --------------------------------------------------------------------------------
#
# Item 8 - User Query: Low mileage honda car with complete safety features
# System Response: 🚗 Civic 2017 (2017)
#  📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 70000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Cruise Control, Climate Control, Front Speakers, Front Camera, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Sun Roof
# 💰 Price (IDR): IDR 251,558,500
# Reference Responses: A Honda City with automatic transmission costs around 200 million rupiah. 2018 car with 20,000 km mileage using gasoline. Equipped with ABS, Air Bags, AM-FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8240, Recall: 0.8816, F1: 0.8518
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.5750
#
# --------------------------------------------------------------------------------
#
# Item 9 - User Query: Toyota 2023 model with complete features under 300 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Toyota Yaris with automatic transmission costs around 260 million rupiah. The 2023 car with a mileage of 37,500 km uses gasoline. Equipped with Air Bags. Car price IDR 260,038,000.
# BERTScore - Precision: 0.8032, Recall: 0.8818, F1: 0.8407
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7544
#
# --------------------------------------------------------------------------------
#
# Item 10 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 190 million rupiah. 2018 car with a mileage of 70,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning. Car price Rp 192,202,000.
# BERTScore - Precision: 0.7892, Recall: 0.8626, F1: 0.8243
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.3973
#
# --------------------------------------------------------------------------------
#
# Item 11 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: Maaf, saya tidak menemukan mobil yang sesuai dengan kriteria Anda.
# Preferensi Anda:
# • Merek: Toyota
# • Tahun: 2023
# • Transmisi: Automatic
# • Rentang Harga: 120.0 - 180.0 juta
# Mungkin Anda ingin:
# 1. Memperluas rentang harga
# 2. Mencoba tahun yang berbeda
# 3. Mencoba merek lain
# Silakan sesuaikan preferensi Anda.
# Reference Responses: A Toyota Passo with automatic transmission costs around 157 million rupiah. The 2014 car with a mileage of 82,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera. Car price IDR IDR 157,153,400.
# BERTScore - Precision: 0.7435, Recall: 0.7759, F1: 0.7593
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.3858
#
# --------------------------------------------------------------------------------
#
# Item 12 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Mira Xs3 with automatic transmission costs around 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM, FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200
# BERTScore - Precision: 0.7903, Recall: 0.8210, F1: 0.8053
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.4723
#
# --------------------------------------------------------------------------------
#
# Item 13 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Alto VXL 2023 (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Every 2018 with 92,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows. Price: IDR 146,130,050.
# BERTScore - Precision: 0.8356, Recall: 0.9111, F1: 0.8717
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7431
#
# --------------------------------------------------------------------------------
#
# Item 14 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira with automatic transmission costs around 200 million rupiah. The 2019 car with a mileage of 37,500 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Car price IDR 206,334,500.
# BERTScore - Precision: 0.8764, Recall: 0.9242, F1: 0.8996
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8017
#
# --------------------------------------------------------------------------------
#
# Item 15 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Alto vxl (2019)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 45000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Heated Seats, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 135,671,943
# Reference Responses: Suzuki Every 2018 with 79,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio. Price: IDR 139,629,100.
# BERTScore - Precision: 0.8078, Recall: 0.9068, F1: 0.8544
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7162
#
# --------------------------------------------------------------------------------
#
# Item 16 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu Mira XSAIII 2021 with 67,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable. Price: IDR 195,028,500.
# BERTScore - Precision: 0.8396, Recall: 0.8768, F1: 0.8578
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.6848
#
# --------------------------------------------------------------------------------
#
# Item 17 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8741, Recall: 0.9320, F1: 0.9021
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9167
#
# --------------------------------------------------------------------------------
#
# Item 18 - User Query: Low mileage Toyota car with complete safety features
# System Response: 🚗 Corolla Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 12300 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Toyota Corolla Gli 2019 with 12,300 km, petrol fuel, and automatic transmission. Features include Air Conditioning. Price: IDR 214,814,000.
# BERTScore - Precision: 0.8150, Recall: 0.9183, F1: 0.8636
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9004
#
# --------------------------------------------------------------------------------
#
# Item 19 - User Query: Looking for a car with manual transmission, price between 150 to 300 million
# System Response: 🚗 Corolla GLI 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 41000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 237,426,000
# Reference Responses: Honda City 2022 with 16,000 km, petrol fuel, and manual transmission. Features include ABS, Air Conditioning, AM FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 226,120,000.
# BERTScore - Precision: 0.8353, Recall: 0.8999, F1: 0.8664
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.4140
#
# --------------------------------------------------------------------------------
#
# Item 20 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: Toyota Passo 2021 with 6,900 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable. Price: IDR 245,905,500.
# BERTScore - Precision: 0.8645, Recall: 0.9306, F1: 0.8963
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9175
#
# --------------------------------------------------------------------------------
#
# Item 21 - User Query: Suzuki car with low kilometers and complete features
# System Response: 🚗 Suzuki Swift 2021 (2021)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 35000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers
# 💰 Price (IDR): IDR 183,722,500
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8287, Recall: 0.8866, F1: 0.8567
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.7940
#
# --------------------------------------------------------------------------------
#
# Item 22 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu Move 2021 with 6,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 197,798,470.
# BERTScore - Precision: 0.8366, Recall: 0.8804, F1: 0.8580
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.6860
#
# --------------------------------------------------------------------------------
#
# Item 23 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Daihatsu Move 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Toyota Yaris 2021 with 31,000 km, petrol fuel, and automatic transmission. Features include Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera. Price: IDR 245,622,850.
# BERTScore - Precision: 0.8284, Recall: 0.9067, F1: 0.8658
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.5238
#
# --------------------------------------------------------------------------------
#
# Item 24 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 25 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 243,079,000
# Reference Responses: Toyota Gli 2019 with 90,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows. Price: IDR 243,079,000.
# BERTScore - Precision: 0.8738, Recall: 0.9371, F1: 0.9043
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9285
#
# --------------------------------------------------------------------------------
#
# Item 26 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response:
# Reference Responses: Toyota Yaris 2021 with 24,000 km, petrol fuel, and automatic transmission. Features include Air Conditioning, Alloy Rims, AM FM Radio, Power Locks, Power Steering, Power Windows. Price: IDR 234,599,500.
# BERTScore - Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# BERT Accuracy: 0.0000
# Cosine Similarity with reference responses:
#   Reference 1: -0.0103
#
# --------------------------------------------------------------------------------
#
# Item 27 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 28 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: Maaf, saya tidak menemukan mobil yang sesuai dengan kriteria Anda.
# Preferensi Anda:
# • Merek: Daihatsu
# • Tahun: 2019
# • Transmisi: Manual
# • Rentang Harga: 100.0 - 250.0 juta
# Mungkin Anda ingin:
# 1. Memperluas rentang harga
# 2. Mencoba tahun yang berbeda
# 3. Mencoba merek lain
# Silakan sesuaikan preferensi Anda.
# Reference Responses: Toyota Corolla GLI 2019 with 41,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable. Price: IDR 237,426,000.
# BERTScore - Precision: 0.7396, Recall: 0.7594, F1: 0.7494
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.1425
#
# --------------------------------------------------------------------------------
#
# Item 29 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Daihatsu Move 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8384, Recall: 0.9083, F1: 0.8719
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8636
#
# --------------------------------------------------------------------------------
#
# Item 30 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira ES 2019 with 57,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 175,243,000.
# BERTScore - Precision: 0.8499, Recall: 0.9151, F1: 0.8813
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.8979
#
# --------------------------------------------------------------------------------
#
# Item 31 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Mira XSAIII 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 67000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 195,028,500
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8376, Recall: 0.9094, F1: 0.8720
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.6048
#
# --------------------------------------------------------------------------------
#
# Item 32 - User Query: Suzuki 2022 model with complete features under 200 million
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 33 - User Query: Suzuki 2023 model with complete features under 200 million
# System Response: 🚗 Alto VXL 2023 (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Alto VXL 2023 with 7,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 166,763,500.
# BERTScore - Precision: 0.8608, Recall: 0.9235, F1: 0.8911
# BERT Accuracy: 1.0000
# Cosine Similarity with reference responses:
#   Reference 1: 0.9065
#
# --------------------------------------------------------------------------------
#
# Average BERT Precision: 0.8048
# Average BERT Recall: 0.8639
# Average BERT F1: 0.8332
# Average BERT Accuracy: 0.9697
# Average Cosine Similarity: 0.6590

# %% [markdown]
# ### Without Accuracy

# %%
# Fungsi untuk menghitung BERTScore
def compute_bertscore(system_response, reference_responses):
    # Pastikan reference_responses adalah list
    if isinstance(reference_responses, str):
        reference_responses = [reference_responses]
    
    # Hitung BERTScore
    P, R, F1 = score([system_response] * len(reference_responses), reference_responses, lang="en", verbose=False)
    
    # Mengembalikan rata-rata BERTScore
    return P.mean().item(), R.mean().item(), F1.mean().item()


# Fungsi untuk menghitung Cosine Similarity menggunakan Sentence-BERT
def compute_cosine_similarity(system_response, reference_responses, model):
    system_embedding = model.encode(system_response, convert_to_tensor=True)
    reference_embeddings = model.encode(reference_responses, convert_to_tensor=True)
    cosine_scores = util.cos_sim(system_embedding, reference_embeddings)
    return cosine_scores

# Memuat data dari file JSON
with open('pre_fine_tuning_evals.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Memuat model Sentence-BERT
model = SentenceTransformer('all-MiniLM-L6-v2')

# Menyimpan hasil evaluasi
bertscore_results = []
cosine_results = []

# Proses evaluasi untuk setiap item dalam data
for item in data:
    system_response = item["system_response"]
    reference_responses = item["reference_responses"]
    
    # Menghitung BERTScore
    bert_precision, bert_recall, bert_f1 = compute_bertscore(system_response, reference_responses)
    bertscore_results.append((bert_precision, bert_recall, bert_f1))
    
    # Menghitung Cosine Similarity
    cosine_scores = compute_cosine_similarity(system_response, reference_responses, model)
    cosine_results.append(cosine_scores)

# Menampilkan hasil BERTScore dan Cosine Similarity untuk setiap item
for i, item in enumerate(data):
    print(f"Item {i+1} - User Query: {item['user_query']}")
    print(f"System Response: {item['system_response']}")
    print(f"Reference Responses: {item['reference_responses']}")
    print(f"BERTScore - Precision: {bertscore_results[i][0]:.4f}, Recall: {bertscore_results[i][1]:.4f}, F1: {bertscore_results[i][2]:.4f}")
    
    # Menampilkan Cosine Similarity untuk setiap reference
    print(f"Cosine Similarity with reference responses:")
    for j, score in enumerate(cosine_results[i][0]):
        print(f"  Reference {j+1}: {score.item():.4f}")
    
    print("\n" + "-"*80 + "\n")

# Menampilkan rata-rata BERTScore untuk seluruh dataset
avg_bert_precision = sum([result[0] for result in bertscore_results]) / len(bertscore_results)
avg_bert_recall = sum([result[1] for result in bertscore_results]) / len(bertscore_results)
avg_bert_f1 = sum([result[2] for result in bertscore_results]) / len(bertscore_results)

print(f"Average BERT Precision: {avg_bert_precision:.4f}")
print(f"Average BERT Recall: {avg_bert_recall:.4f}")
print(f"Average BERT F1: {avg_bert_f1:.4f}")

# Menampilkan rata-rata Cosine Similarity untuk seluruh dataset
avg_cosine_similarity = sum([score.mean().item() for score in cosine_results]) / len(cosine_results)
print(f"Average Cosine Similarity: {avg_cosine_similarity:.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Item 1 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: 🚗 Toyota Passo 2014 (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 82000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 157,153,400
# Reference Responses: Toyota Passo Model 2013 with automatic transmission price below 150 million rupiah. A 2013 car with a mileage of 90,000 km using gasoline. Equipped with ABS and air bag safety features, AC comfort, audio, rear camera, and keyless entry. Car price IDR 144,151,500.
# BERTScore - Precision: 0.8090, Recall: 0.8753, F1: 0.8408
# Cosine Similarity with reference responses:
#   Reference 1: 0.7866
#
# --------------------------------------------------------------------------------
#
# Item 2 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Altis 2016 (2016)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 80000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Seat Entertainment, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 196,159,100
# Reference Responses: Daihatsu Mira Xs3 2020 model with automatic transmission is priced below 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline fuel. Equipped with ABS, Air Bags, Air Conditioning, AM FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200.
# BERTScore - Precision: 0.8304, Recall: 0.8855, F1: 0.8571
# Cosine Similarity with reference responses:
#   Reference 1: 0.4657
#
# --------------------------------------------------------------------------------
#
# Item 3 - User Query: Car with complete safety features between 150-300 million
# System Response: 🚗 Toyota Grande (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 145000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cruise Control, DVD Player, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Sun Roof, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 224,706,750
# Reference Responses: Honda City 2018 with automatic transmission is priced between 150-300 million rupiah. Car year 2018 with a mileage of 107,000 km using gasoline. Equipped with ABS, AM FM Radio, CD Player, Front Speakers, Immobilizer Key, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 214,814,000.
# BERTScore - Precision: 0.8319, Recall: 0.8845, F1: 0.8574
# Cosine Similarity with reference responses:
#   Reference 1: 0.2708
#
# --------------------------------------------------------------------------------
#
# Item 4 - User Query: Car with good entertainment system around 180 million
# System Response: 🚗 Gli Auto 2014 (2014)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning, DVD Player, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable
# 💰 Price (IDR): IDR 180,896,000
# Reference Responses: Honda City 2018 with automatic transmission costs around 180 million rupiah. Car year 2018 with a mileage of 20,000 km using gasoline. Equipped with ABS, Air Bags, AM FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8182, Recall: 0.8699, F1: 0.8433
# Cosine Similarity with reference responses:
#   Reference 1: 0.4177
#
# --------------------------------------------------------------------------------
#
# Item 5 - User Query: Find me a Daihatsu automatic with complete features
# System Response: 🚗 Daihatsu Mira 2019 (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 51000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Power Locks, Power Mirrors, Power Steering, Power Windows
# 💰 Price (IDR): IDR 179,482,750
# Reference Responses: A Daihatsu Mira XSA3 with automatic transmission costs around 170 million rupiah. Car year 2018 with a mileage of 79,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM - FM Radio, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Power Locks. Car price IDR 178,069,500.
# BERTScore - Precision: 0.8301, Recall: 0.8641, F1: 0.8468
# Cosine Similarity with reference responses:
#   Reference 1: 0.7473
#
# --------------------------------------------------------------------------------
#
# Item 6 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 200 million rupiah. 2018 car with a mileage of 5,800 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price Rp 197,855,000.
# BERTScore - Precision: 0.8250, Recall: 0.9007, F1: 0.8612
# Cosine Similarity with reference responses:
#   Reference 1: 0.7474
#
# --------------------------------------------------------------------------------
#
# Item 7 - User Query: Toyota with leather seats and automatic transmission
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: A Toyota Altis with automatic transmission costs around 250 million rupiah. 2018 car with 55,000 km mileage using gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AMFM Radio, CD Player. Car price IDR 245,905,500.
# BERTScore - Precision: 0.8190, Recall: 0.8910, F1: 0.8535
# Cosine Similarity with reference responses:
#   Reference 1: 0.5546
#
# --------------------------------------------------------------------------------
#
# Item 8 - User Query: Low mileage honda car with complete safety features
# System Response: 🚗 Civic 2017 (2017)
#  📝 Car Detail:
# • Brands: Honda
# • KMs Driven: 70000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Cruise Control, Climate Control, Front Speakers, Front Camera, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Sun Roof
# 💰 Price (IDR): IDR 251,558,500
# Reference Responses: A Honda City with automatic transmission costs around 200 million rupiah. 2018 car with 20,000 km mileage using gasoline. Equipped with ABS, Air Bags, AM-FM Radio, Cool Box, Immobilizer Key, Power Locks, Power Mirrors, Power Steering, Power Windows. Car price IDR 214,531,350.
# BERTScore - Precision: 0.8240, Recall: 0.8816, F1: 0.8518
# Cosine Similarity with reference responses:
#   Reference 1: 0.5750
#
# --------------------------------------------------------------------------------
#
# Item 9 - User Query: Toyota 2023 model with complete features under 300 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Toyota Yaris with automatic transmission costs around 260 million rupiah. The 2023 car with a mileage of 37,500 km uses gasoline. Equipped with Air Bags. Car price IDR 260,038,000.
# BERTScore - Precision: 0.8032, Recall: 0.8818, F1: 0.8407
# Cosine Similarity with reference responses:
#   Reference 1: 0.7544
#
# --------------------------------------------------------------------------------
#
# Item 10 - User Query: Cars from 2018-2020 under 250 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Daihatsu Mira X with automatic transmission costs around 190 million rupiah. 2018 car with a mileage of 70,000 km using gasoline. Equipped with ABS, Air Bags, Air Conditioning. Car price Rp 192,202,000.
# BERTScore - Precision: 0.7892, Recall: 0.8626, F1: 0.8243
# Cosine Similarity with reference responses:
#   Reference 1: 0.3973
#
# --------------------------------------------------------------------------------
#
# Item 11 - User Query: Looking for a Toyota car under 150 million with automatic transmission
# System Response: Maaf, saya tidak menemukan mobil yang sesuai dengan kriteria Anda.
# Preferensi Anda:
# • Merek: Toyota
# • Tahun: 2023
# • Transmisi: Automatic
# • Rentang Harga: 120.0 - 180.0 juta
# Mungkin Anda ingin:
# 1. Memperluas rentang harga
# 2. Mencoba tahun yang berbeda
# 3. Mencoba merek lain
# Silakan sesuaikan preferensi Anda.
# Reference Responses: A Toyota Passo with automatic transmission costs around 157 million rupiah. The 2014 car with a mileage of 82,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, CD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear speakers, Rear Camera. Car price IDR IDR 157,153,400.
# BERTScore - Precision: 0.7435, Recall: 0.7759, F1: 0.7593
# Cosine Similarity with reference responses:
#   Reference 1: 0.3858
#
# --------------------------------------------------------------------------------
#
# Item 12 - User Query: Find me a car with sunroof and leather seats under 200 million
# System Response: 🚗 Toyota Yaris (2023)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 16000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Bags
# 💰 Price (IDR): IDR 260,038,000
# Reference Responses: A Mira Xs3 with automatic transmission costs around 200 million rupiah. The 2020 car with a mileage of 53,000 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, AM, FM Radio, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, USB and Auxillary Cable. Car price IDR 200,116,200
# BERTScore - Precision: 0.7903, Recall: 0.8210, F1: 0.8053
# Cosine Similarity with reference responses:
#   Reference 1: 0.4723
#
# --------------------------------------------------------------------------------
#
# Item 13 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Alto VXL 2023 (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Every 2018 with 92,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Immobilizer Key, Keyless Entry, Power Locks, Power Steering, Power Windows. Price: IDR 146,130,050.
# BERTScore - Precision: 0.8356, Recall: 0.9111, F1: 0.8717
# Cosine Similarity with reference responses:
#   Reference 1: 0.7431
#
# --------------------------------------------------------------------------------
#
# Item 14 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: A Daihatsu Mira with automatic transmission costs around 200 million rupiah. The 2019 car with a mileage of 37,500 km uses gasoline. Equipped with ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Car price IDR 206,334,500.
# BERTScore - Precision: 0.8764, Recall: 0.9242, F1: 0.8996
# Cosine Similarity with reference responses:
#   Reference 1: 0.8017
#
# --------------------------------------------------------------------------------
#
# Item 15 - User Query: Low mileage suzuki car with complete safety features
# System Response: 🚗 Alto vxl (2019)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 45000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Heated Seats, Immobilizer Key, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 135,671,943
# Reference Responses: Suzuki Every 2018 with 79,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio. Price: IDR 139,629,100.
# BERTScore - Precision: 0.8078, Recall: 0.9068, F1: 0.8544
# Cosine Similarity with reference responses:
#   Reference 1: 0.7162
#
# --------------------------------------------------------------------------------
#
# Item 16 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu Mira XSAIII 2021 with 67,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable. Price: IDR 195,028,500.
# BERTScore - Precision: 0.8396, Recall: 0.8768, F1: 0.8578
# Cosine Similarity with reference responses:
#   Reference 1: 0.6848
#
# --------------------------------------------------------------------------------
#
# Item 17 - User Query: Daihatsu 2019 model with complete features under 300 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8741, Recall: 0.9320, F1: 0.9021
# Cosine Similarity with reference responses:
#   Reference 1: 0.9167
#
# --------------------------------------------------------------------------------
#
# Item 18 - User Query: Low mileage Toyota car with complete safety features
# System Response: 🚗 Corolla Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 12300 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • Air Conditioning
# 💰 Price (IDR): IDR 214,814,000
# Reference Responses: Toyota Corolla Gli 2019 with 12,300 km, petrol fuel, and automatic transmission. Features include Air Conditioning. Price: IDR 214,814,000.
# BERTScore - Precision: 0.8150, Recall: 0.9183, F1: 0.8636
# Cosine Similarity with reference responses:
#   Reference 1: 0.9004
#
# --------------------------------------------------------------------------------
#
# Item 19 - User Query: Looking for a car with manual transmission, price between 150 to 300 million
# System Response: 🚗 Corolla GLI 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 41000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable
# 💰 Price (IDR): IDR 237,426,000
# Reference Responses: Honda City 2022 with 16,000 km, petrol fuel, and manual transmission. Features include ABS, Air Conditioning, AM FM Radio, Front Speakers, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 226,120,000.
# BERTScore - Precision: 0.8353, Recall: 0.8999, F1: 0.8664
# Cosine Similarity with reference responses:
#   Reference 1: 0.4140
#
# --------------------------------------------------------------------------------
#
# Item 20 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Toyota Passo (2021)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 6900 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 245,905,500
# Reference Responses: Toyota Passo 2021 with 6,900 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, CD Player, DVD Player, Front Speakers, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Camera, USB and Auxillary Cable. Price: IDR 245,905,500.
# BERTScore - Precision: 0.8645, Recall: 0.9306, F1: 0.8963
# Cosine Similarity with reference responses:
#   Reference 1: 0.9175
#
# --------------------------------------------------------------------------------
#
# Item 21 - User Query: Suzuki car with low kilometers and complete features
# System Response: 🚗 Suzuki Swift 2021 (2021)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 35000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers
# 💰 Price (IDR): IDR 183,722,500
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8287, Recall: 0.8866, F1: 0.8567
# Cosine Similarity with reference responses:
#   Reference 1: 0.7940
#
# --------------------------------------------------------------------------------
#
# Item 22 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Not Mentioned (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 3700 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 201,812,100
# Reference Responses: Daihatsu Move 2021 with 6,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 197,798,470.
# BERTScore - Precision: 0.8366, Recall: 0.8804, F1: 0.8580
# Cosine Similarity with reference responses:
#   Reference 1: 0.6860
#
# --------------------------------------------------------------------------------
#
# Item 23 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response: 🚗 Daihatsu Move 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Toyota Yaris 2021 with 31,000 km, petrol fuel, and automatic transmission. Features include Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Camera. Price: IDR 245,622,850.
# BERTScore - Precision: 0.8284, Recall: 0.9067, F1: 0.8658
# Cosine Similarity with reference responses:
#   Reference 1: 0.5238
#
# --------------------------------------------------------------------------------
#
# Item 24 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 25 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: 🚗 Toyota Gli 2019 (2019)
#  📝 Car Detail:
# • Brands: Toyota
# • KMs Driven: 90000 km
# • Fuel: Petrol
# • Transmission: Manual
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows
# 💰 Price (IDR): IDR 243,079,000
# Reference Responses: Toyota Gli 2019 with 90,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Cruise Control, Climate Control, DVD Player, Front Speakers, Front Camera, Heated Seats, Immobilizer Key, Power Locks, Power Steering, Power Windows. Price: IDR 243,079,000.
# BERTScore - Precision: 0.8738, Recall: 0.9371, F1: 0.9043
# Cosine Similarity with reference responses:
#   Reference 1: 0.9285
#
# --------------------------------------------------------------------------------
#
# Item 26 - User Query: Find a car in 2021 automatic transmission with the most complete features for around 250 million
# System Response:
# Reference Responses: Toyota Yaris 2021 with 24,000 km, petrol fuel, and automatic transmission. Features include Air Conditioning, Alloy Rims, AM FM Radio, Power Locks, Power Steering, Power Windows. Price: IDR 234,599,500.
# BERTScore - Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# Cosine Similarity with reference responses:
#   Reference 1: -0.0103
#
# --------------------------------------------------------------------------------
#
# Item 27 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira 2019 with 37,500 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable. Price: IDR 206,334,500.
# BERTScore - Precision: 0.8737, Recall: 0.9314, F1: 0.9016
# Cosine Similarity with reference responses:
#   Reference 1: 0.9171
#
# --------------------------------------------------------------------------------
#
# Item 28 - User Query: Looking for a car with manual transmission, price between 100 to 250 million
# System Response: Maaf, saya tidak menemukan mobil yang sesuai dengan kriteria Anda.
# Preferensi Anda:
# • Merek: Daihatsu
# • Tahun: 2019
# • Transmisi: Manual
# • Rentang Harga: 100.0 - 250.0 juta
# Mungkin Anda ingin:
# 1. Memperluas rentang harga
# 2. Mencoba tahun yang berbeda
# 3. Mencoba merek lain
# Silakan sesuaikan preferensi Anda.
# Reference Responses: Toyota Corolla GLI 2019 with 41,000 km, petrol fuel, and manual transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, AM FM Radio, CD Player, Cassette Player, Cool Box, Front Speakers, Power Locks, Power Steering, Power Windows, Rear Speakers, USB and Auxillary Cable. Price: IDR 237,426,000.
# BERTScore - Precision: 0.7396, Recall: 0.7594, F1: 0.7494
# Cosine Similarity with reference responses:
#   Reference 1: 0.1425
#
# --------------------------------------------------------------------------------
#
# Item 29 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Daihatsu Move 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 6500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Cool Box, Climate Control, DVD Player, Front Speakers, Front Camera, Immobilizer Key, Power Locks, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 197,798,470
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8384, Recall: 0.9083, F1: 0.8719
# Cosine Similarity with reference responses:
#   Reference 1: 0.8636
#
# --------------------------------------------------------------------------------
#
# Item 30 - User Query: Daihatsu 2019 model with complete features under 200 million
# System Response: 🚗 Daihatsu Mira (2019)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 37500 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera, USB and Auxillary Cable
# 💰 Price (IDR): IDR 206,334,500
# Reference Responses: Daihatsu Mira ES 2019 with 57,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 175,243,000.
# BERTScore - Precision: 0.8499, Recall: 0.9151, F1: 0.8813
# Cosine Similarity with reference responses:
#   Reference 1: 0.8979
#
# --------------------------------------------------------------------------------
#
# Item 31 - User Query: Daihatsu 2021 model with complete features under 200 million
# System Response: 🚗 Mira XSAIII 2021 (2021)
#  📝 Car Detail:
# • Brands: Daihatsu
# • KMs Driven: 67000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, Alloy Rims, AM, FM Radio, CD Player, Cassette Player, Climate Control, DVD Player, Front Speakers, Heated Seats, Immobilizer Key, Keyless Entry, Navigation System, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear AC Vents, Rear Speakers, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 195,028,500
# Reference Responses: Daihatsu 2021 with 3,700 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, Alloy Rims, DVD Player, Keyless Entry, Power Locks, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 201,812,100.
# BERTScore - Precision: 0.8376, Recall: 0.9094, F1: 0.8720
# Cosine Similarity with reference responses:
#   Reference 1: 0.6048
#
# --------------------------------------------------------------------------------
#
# Item 32 - User Query: Suzuki 2022 model with complete features under 200 million
# System Response: 🚗 Suzuki WagonR (2022)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 62000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Conditioning, Alloy Rims, AM, FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable
# 💰 Price (IDR): IDR 169,590,000
# Reference Responses: Suzuki WagonR 2022 with 62,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Conditioning, Alloy Rims, AM FM Radio, Front Speakers, Power Steering, Power Windows, Rear Speakers, Rear Camera, Steering Switches, USB and Auxillary Cable. Price: IDR 169,590,000.
# BERTScore - Precision: 0.8557, Recall: 0.9265, F1: 0.8897
# Cosine Similarity with reference responses:
#   Reference 1: 0.9056
#
# --------------------------------------------------------------------------------
#
# Item 33 - User Query: Suzuki 2023 model with complete features under 200 million
# System Response: 🚗 Alto VXL 2023 (2023)
#  📝 Car Detail:
# • Brands: Suzuki
# • KMs Driven: 7000 km
# • Fuel: Petrol
# • Transmission: Automatic
# 🌟 Car Features:
# • ABS, Air Bags, Air Conditioning, AM, FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera
# 💰 Price (IDR): IDR 166,763,500
# Reference Responses: Suzuki Alto VXL 2023 with 7,000 km, petrol fuel, and automatic transmission. Features include ABS, Air Bags, Air Conditioning, AM FM Radio, Front Speakers, Immobilizer Key, Keyless Entry, Power Locks, Power Mirrors, Power Steering, Power Windows, Rear Speakers, Rear Camera. Price: IDR 166,763,500.
# BERTScore - Precision: 0.8608, Recall: 0.9235, F1: 0.8911
# Cosine Similarity with reference responses:
#   Reference 1: 0.9065
#
# --------------------------------------------------------------------------------
#
# Average BERT Precision: 0.8048
# Average BERT Recall: 0.8639
# Average BERT F1: 0.8332
# Average Cosine Similarity: 0.6590
